# %%
import numpy as np
import NN

# %%
layers = [4,3,4,2]
nn = NN.neuralnet(layers)

# %%
input_layer = np.array([3, 4, 7, 2])
out = nn.output(input_layer)
out
# Out:
# array([0.60298239, 0.20240616])

# %%
nn.printWeights()
# Out:
# Layer 0 -> 1
# -3.27E-01  +7.17E-02  +1.16E+00  +1.06E+00
# -2.99E-01  -4.63E-01  +1.02E+00  -7.12E-01
# -1.74E+00  +5.12E-01  -8.02E-01  +3.17E-01
#
# Layer 1 -> 2
# -6.21E-01  +9.22E-01  -9.42E-01
# -1.97E-01  +1.37E-01  -4.20E-01
# -2.79E-01  +5.35E-01  +3.63E-01
# -3.14E-02  -1.13E+00  +1.75E+00
#
# Layer 2 -> 3
# +2.56E-01  -7.68E-01  +1.15E-01  +1.70E+00
# +1.16E+00  -9.42E-01  -7.61E-01  -1.01E+00

# %%
nn.printBiases()
# Out:
# Layer 1
# +1.31E+00  -6.06E-01  -1.65E+00
#
# Layer 2
# -8.08E-02  -2.30E-01  -2.74E-01  -2.07E+00
#
# Layer 3
# +4.80E-01  -1.18E+00

# %%
fig = nn.draw(showBias = False)
